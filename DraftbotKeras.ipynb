# %%
import os
import json
import ast
import numpy as np
import pandas as pd
from collections import Counter
pd.set_option('display.max_colwidth', 900)

# %%
def get_cardset(drafts):
    cardset = set()
    for draft in drafts:
        for pack in draft['picks']:
            for card in pack:
                cardset.add(card)
    carddict = {card: i for i, card in enumerate(cardset)}
    carddict['<unk>'] = -1
    return carddict

# %%
def parse_draft_to_flooey_format(draft):
    players = draft['picks']
    cards_per_pack = int(len(players[0]) / 3)
    packs = []
    for pack_index in range(3):
        choices = []
        for pick_index in range(cards_per_pack):
            options = []
            idx = pick_index
            while idx < cards_per_pack:
                options.append(players[(idx - pick_index) % 8][idx + pack_index * cards_per_pack])
                idx += 1
            choices.append(options)
        packs.append(choices)
    return packs

# %%
def vectorize_drafts(drafts):
    cardset = get_cardset(drafts)
    flooey_drafts = [parse_draft_to_flooey_format(draft) for draft in drafts]
    return [vectorize_draft(draft, cardset) for draft in flooey_drafts]

def vectorize_draft(draft, cardset):
    draft_x = np.zeros([3, len(draft[0][0]), len(cardset) * 2])
    draft_y = np.zeros([3, len(draft[0][0]), len(cardset)])
    pile = np.zeros(len(cardset))
    for pa, pack in enumerate(draft):
        for pi, pick in enumerate(pack):
            draft_y[pa][pi][cardset.get(pick[0], -1)] = 1
            x1 = np.zeros(len(cardset))
            for card in pick:
                if card in cardset:
                    x1[cardset[card]] += 1
                else:
                    # print("Unknown card:", card)
                    x1[-1] += 1
            draft_x[pa][pi] = np.append(x1, pile)
            pile[cardset.get(pick[0], -1)] += 1
            
    return {'draft_x': draft_x, 'draft_y': draft_y}

# %%
def draft_to_df(draftx, drafty):
    picks = []
    piles = []
    selections = []
    for (dx, dy) in zip(draftx, drafty):
        pick = []
        pile = []
        for card in np.where(dx != 0)[0]:
            if card < len(cardset):
                for i in range(int(dx[card])):
                    pick.append(invcardset[card])
            else:
                for i in range(int(dx[card])):
                    pile.append(invcardset[card - len(cardset)])
        picks.append(pick)
        piles.append(pile)
        selections.append(invcardset[np.where(dy==1)[0][0]])
    return pd.DataFrame({'picks': picks, 'piles': piles, 'selections': selections})

# %%
def load_draft(draft_file):
    return ast.literal_eval(open('drafts/' + mtgset + '/' + draft_file, 'r').read())

# %%
mtgset = 'DOM'
alldrafts = os.listdir('drafts/' + mtgset)
drafts = [load_draft(draft) for draft in alldrafts[:100]]
cardset = get_cardset(drafts)
invcardset = {v: k for k, v in cardset.items()}

# %%
drafts[0]
# Out:
# {'format': 'DOM',
#  'picks': [['The_Eldest_Reborn',
#    'Sylvan_Awakening',
#    'Baloth_Gorger',
#    'Urgoros_the_Empty_One',
#    'Cabal_Paladin',
#    'Windgrace_Acolyte',
#    'Dark_Bargain',
#    'Blessing_of_Belzenlok',
#    'Stronghold_Confessor',
#    'Arcane_Flight',
#    'Stronghold_Confessor',
#    'Guardians_of_Koilos',
#    'Rat_Colony',
#    'Tragic_Poet',
#    'Settle_the_Score',
#    'Windgrace_Acolyte',
#    'Wild_Onslaught',
#    "Navigator's_Compass",
#    'Deathbloom_Thallid',
#    'Grow_from_the_Ashes',
#    'Grow_from_the_Ashes',
#    'Slimefoot_the_Stowaway',
#    'Saproling_Migration',
#    'Broken_Bond',
#    'Jousting_Lance',
#    'Garna_the_Bloodflame',
#    'Feral_Abomination',
#    'Rat_Colony',
#    'Vicious_Offering',
#    'Cast_Down',
#    'Dark_Bargain',
#    'Fungal_Infection',
#    'Spore_Swarm',
#    'Slimefoot_the_Stowaway',
#    'Bloodtallow_Candle',
#    'Soul_Salvage',
#    'Skittering_Surveyor',
#    "Gaea's_Protector",
#    'Benalish_Honor_Guard',
#    'Demonic_Vigor',
#    "Warlord's_Fury",
#    'Cabal_Stronghold'],
#   ['Fiery_Intervention',
#    'Settle_the_Score',
#    'Run_Amok',
#    "On_Serra's_Wings",
#    'Shivan_Fire',
#    'Call_the_Cavalry',
#    'Run_Amok',
#    'Keldon_Warcaller',
#    'Memorial_to_Glory',
#    'Serra_Disciple',
#    'Slinn_Voda_the_Rising_Deep',
#    'Relic_Runner',
#    'Ghitu_Lavarunner',
#    'Homarid_Explorer',
#    'Serra_Angel',
#    'Helm_of_the_Host',
#    'Memorial_to_Glory',
#    "Urza's_Tome",
#    "Gideon's_Reproach",
#    'Clifftop_Retreat',
#    'Skittering_Surveyor',
#    'Keldon_Overseer',
#    'Dub',
#    'Sparring_Construct',
#    'Short_Sword',
#    'Keldon_Warcaller',
#    'Garna_the_Bloodflame',
#    'Primordial_Wurm',
#    'Baird_Steward_of_Argive',
#    'Serra_Angel',
#    "Jaya's_Immolating_Inferno",
#    'Shivan_Fire',
#    'Aven_Sentry',
#    'Healing_Grace',
#    'Rampaging_Cyclops',
#    'Keldon_Overseer',
#    'Thallid_Omnivore',
#    'Radiating_Lightning',
#    'Keldon_Overseer',
#    'Fire_Elemental',
#    'Radiating_Lightning',
#    'Ghitu_Lavarunner'],
#   ['Seal_Away',
#    'Arvad_the_Cursed',
#    'Baird_Steward_of_Argive',
#    'Call_the_Cavalry',
#    'Aven_Sentry',
#    "Gideon's_Reproach",
#    'Adamant_Will',
#    'Drudge_Sentinel',
#    'Serra_Disciple',
#    'Short_Sword',
#    'Cabal_Evangel',
#    "Artificer's_Assistant",
#    'Cold-Water_Snapper',
#    'Amaranthine_Wall',
#    'Serra_Angel',
#    'Serra_Angel',
#    "Raff_Capashen_Ship's_Mage",
#    'Daring_Archaeologist',
#    'Slinn_Voda_the_Rising_Deep',
#    'Academy_Journeymage',
#    'Deep_Freeze',
#    'Sergeant-at-Arms',
#    'Opt',
#    'Divination',
#    'Adamant_Will',
#    'Charge',
#    'Charge',
#    'Adamant_Will',
#    'Triumph_of_Gerrard',
#    'Blessed_Light',
#    'Weight_of_Memory',
#    "Raff_Capashen_Ship's_Mage",
#    'Blessed_Light',
#    'Academy_Drake',
#    'Opt',
#    'Aven_Sentry',
#    'Invoke_the_Divine',
#    "Artificer's_Assistant",
#    'Invoke_the_Divine',
#    'Guardians_of_Koilos',
#    'The_Antiquities_War',
#    'Board_the_Weatherlight'],
#   ['Territorial_Allosaurus',
#    'Fiery_Intervention',
#    'Goblin_Warchief',
#    "Navigator's_Compass",
#    'Llanowar_Envoy',
#    'Keldon_Overseer',
#    'Ancient_Animus',
#    'Powerstone_Shard',
#    'Mammoth_Spider',
#    'Gift_of_Growth',
#    'Pierce_the_Sky',
#    'Arbor_Armament',
#    'Arbor_Armament',
#    'Tolarian_Scholar',
#    'Two-Headed_Giant',
#    'Fiery_Intervention',
#    'Keldon_Overseer',
#    'Keldon_Overseer',
#    'Firefist_Adept',
#    'Yavimaya_Sapherd',
#    'Shield_of_the_Realm',
#    'Gift_of_Growth',
#    'Adventurous_Impulse',
#    'Gift_of_Growth',
#    'Pierce_the_Sky',
#    "Gaea's_Protector",
#    "Gaea's_Blessing",
#    'Ghitu_Chronicler',
#    'Untamed_Kavu',
#    'Goblin_Warchief',
#    'Fiery_Intervention',
#    "Navigator's_Compass",
#    "Wizard's_Lightning",
#    'Gift_of_Growth',
#    "Sorcerer's_Wand",
#    'Grow_from_the_Ashes',
#    'Broken_Bond',
#    'Firefist_Adept',
#    'Llanowar_Scout',
#    'Seismic_Shift',
#    "Warlord's_Fury",
#    'Skirk_Prospector'],
#   ['Aryel_Knight_of_Windgrace',
#    'The_Eldest_Reborn',
#    'Deathbloom_Thallid',
#    'Mox_Amber',
#    'Thallid_Omnivore',
#    'Demonic_Vigor',
#    'Memorial_to_Folly',
#    'Naban_Dean_of_Iteration',
#    'Caligo_Skin-Witch',
#    'Powerstone_Shard',
#    'Mesa_Unicorn',
#    'Guardians_of_Koilos',
#    'Cloudreader_Sphinx',
#    'Unwind',
#    'Untamed_Kavu',
#    'Eviscerate',
#    'Deathbloom_Thallid',
#    'Fall_of_the_Thran',
#    'Sergeant-at-Arms',
#    "On_Serra's_Wings",
#    "Gideon's_Reproach",
#    'Call_the_Cavalry',
#    'Call_the_Cavalry',
#    'Stronghold_Confessor',
#    'Excavation_Elephant',
#    'Thallid_Omnivore',
#    'Radiating_Lightning',
#    'Frenzied_Rage',
#    'Dread_Shade',
#    'Deathbloom_Thallid',
#    'Blessed_Light',
#    'Kwende_Pride_of_Femeref',
#    'Call_the_Cavalry',
#    "D'Avenant_Trapper",
#    'Aven_Sentry',
#    'Soul_Salvage',
#    'Memorial_to_Folly',
#    'Excavation_Elephant',
#    'Powerstone_Shard',
#    'Mammoth_Spider',
#    'Charge',
#    'Cabal_Evangel'],
#   ["Wizard's_Lightning",
#    'Diligent_Excavator',
#    'Fiery_Intervention',
#    "Urza's_Tome",
#    'Bloodtallow_Candle',
#    'Sparring_Construct',
#    'Fervent_Strike',
#    'Guardians_of_Koilos',
#    'Radiating_Lightning',
#    'Fire_Elemental',
#    'Rat_Colony',
#    'Pardic_Wanderer',
#    'Aesthir_Glider',
#    'Ghitu_Lavarunner',
#    'Shivan_Fire',
#    'Fiery_Intervention',
#    'Keldon_Overseer',
#    'Adeliz_the_Cinder_Wind',
#    'Relic_Runner',
#    'Adeliz_the_Cinder_Wind',
#    'Radiating_Lightning',
#    'Cloudreader_Sphinx',
#    'Rescue',
#    'Serra_Disciple',
#    'Ghitu_Lavarunner',
#    'Squee_the_Immortal',
#    'Fire_Elemental',
#    'Ghitu_Lavarunner',
#    'Goblin_Warchief',
#    'Vodalian_Arcanist',
#    'Warcry_Phoenix',
#    'Jhoira_Weatherlight_Captain',
#    'Academy_Drake',
#    'Sulfur_Falls',
#    'Shivan_Fire',
#    'Adeliz_the_Cinder_Wind',
#    'Academy_Journeymage',
#    "Artificer's_Assistant",
#    'Guardians_of_Koilos',
#    'Seismic_Shift',
#    'Adventurous_Impulse',
#    "Gaea's_Protector"],
#   ['Llanowar_Elves',
#    'Vicious_Offering',
#    "Sorcerer's_Wand",
#    'Llanowar_Elves',
#    'Sylvan_Awakening',
#    'Sparring_Construct',
#    'Llanowar_Envoy',
#    'Broken_Bond',
#    'Primordial_Wurm',
#    'Arbor_Armament',
#    "Wizard's_Retort",
#    'Rona_Disciple_of_Gix',
#    'Rona_Disciple_of_Gix',
#    'Invoke_the_Divine',
#    "Wizard's_Lightning",
#    'Vicious_Offering',
#    'Eviscerate',
#    'Blink_of_an_Eye',
#    'Divination',
#    'Thallid_Omnivore',
#    'Windgrace_Acolyte',
#    'Lingering_Phantom',
#    'Opt',
#    'Soul_Salvage',
#    'Guardians_of_Koilos',
#    'Voltaic_Servant',
#    'Cabal_Evangel',
#    'Feral_Abomination',
#    'Academy_Drake',
#    'Torgaar_Famine_Incarnate',
#    'Yargle_Glutton_of_Urborg',
#    'Windgrace_Acolyte',
#    'Rescue',
#    'Academy_Journeymage',
#    'Rona_Disciple_of_Gix',
#    'Fungal_Infection',
#    'Syncopate',
#    'Divination',
#    'Drudge_Sentinel',
#    'Divest',
#    'Rat_Colony',
#    'Oath_of_Teferi'],
#   ['Elfhame_Druid',
#    'Tatyova_Benthic_Druid',
#    'Yavimaya_Sapherd',
#    'Llanowar_Scout',
#    'Spore_Swarm',
#    'Blink_of_an_Eye',
#    'Arcane_Flight',
#    'Hinterland_Harbor',
#    'Weight_of_Memory',
#    'Hinterland_Harbor',
#    'Befuddle',
#    "Artificer's_Assistant",
#    'Unwind',
#    'Rat_Colony',
#    'Baloth_Gorger',
#    'Icy_Manipulator',
#    'Naban_Dean_of_Iteration',
#    'Cloudreader_Sphinx',
#    'Academy_Journeymage',
#    'Naban_Dean_of_Iteration',
#    'Fungal_Plots',
#    "Curator's_Ward",
#    'Arcane_Flight',
#    'Gift_of_Growth',
#    'Opt',
#    'Mammoth_Spider',
#    'Divest',
#    'Frenzied_Rage',
#    'Grow_from_the_Ashes',
#    "Wizard's_Retort",
#    'Ancient_Animus',
#    'Yavimaya_Sapherd',
#    'Divination',
#    'Ancient_Animus',
#    "Sorcerer's_Wand",
#    'Rescue',
#    'Syncopate',
#    'Zhalfirin_Void',
#    'Powerstone_Shard',
#    "Gaea's_Protector",
#    'Tragic_Poet',
#    'Tragic_Poet']]}

# %%
parse_draft_to_flooey_format(drafts[0])
# Out:
# [[['The_Eldest_Reborn',
#    'Settle_the_Score',
#    'Baird_Steward_of_Argive',
#    "Navigator's_Compass",
#    'Thallid_Omnivore',
#    'Sparring_Construct',
#    'Llanowar_Envoy',
#    'Hinterland_Harbor',
#    'Stronghold_Confessor',
#    'Serra_Disciple',
#    'Cabal_Evangel',
#    'Arbor_Armament',
#    'Cloudreader_Sphinx',
#    'Ghitu_Lavarunner'],
#   ['Sylvan_Awakening',
#    'Run_Amok',
#    'Call_the_Cavalry',
#    'Llanowar_Envoy',
#    'Demonic_Vigor',
#    'Fervent_Strike',
#    'Broken_Bond',
#    'Weight_of_Memory',
#    'Arcane_Flight',
#    'Slinn_Voda_the_Rising_Deep',
#    "Artificer's_Assistant",
#    'Arbor_Armament',
#    'Unwind'],
#   ['Baloth_Gorger',
#    "On_Serra's_Wings",
#    'Aven_Sentry',
#    'Keldon_Overseer',
#    'Memorial_to_Folly',
#    'Guardians_of_Koilos',
#    'Primordial_Wurm',
#    'Hinterland_Harbor',
#    'Stronghold_Confessor',
#    'Relic_Runner',
#    'Cold-Water_Snapper',
#    'Tolarian_Scholar'],
#   ['Urgoros_the_Empty_One',
#    'Shivan_Fire',
#    "Gideon's_Reproach",
#    'Ancient_Animus',
#    'Naban_Dean_of_Iteration',
#    'Radiating_Lightning',
#    'Arbor_Armament',
#    'Befuddle',
#    'Guardians_of_Koilos',
#    'Ghitu_Lavarunner',
#    'Amaranthine_Wall'],
#   ['Cabal_Paladin',
#    'Call_the_Cavalry',
#    'Adamant_Will',
#    'Powerstone_Shard',
#    'Caligo_Skin-Witch',
#    'Fire_Elemental',
#    "Wizard's_Retort",
#    "Artificer's_Assistant",
#    'Rat_Colony',
#    'Homarid_Explorer'],
#   ['Windgrace_Acolyte',
#    'Run_Amok',
#    'Drudge_Sentinel',
#    'Mammoth_Spider',
#    'Powerstone_Shard',
#    'Rat_Colony',
#    'Rona_Disciple_of_Gix',
#    'Unwind',
#    'Tragic_Poet'],
#   ['Dark_Bargain',
#    'Keldon_Warcaller',
#    'Serra_Disciple',
#    'Gift_of_Growth',
#    'Mesa_Unicorn',
#    'Pardic_Wanderer',
#    'Rona_Disciple_of_Gix',
#    'Rat_Colony'],
#   ['Blessing_of_Belzenlok',
#    'Memorial_to_Glory',
#    'Short_Sword',
#    'Pierce_the_Sky',
#    'Guardians_of_Koilos',
#    'Aesthir_Glider',
#    'Invoke_the_Divine'],
#   ['Stronghold_Confessor',
#    'Serra_Disciple',
#    'Cabal_Evangel',
#    'Arbor_Armament',
#    'Cloudreader_Sphinx',
#    'Ghitu_Lavarunner'],
#   ['Arcane_Flight',
#    'Slinn_Voda_the_Rising_Deep',
#    "Artificer's_Assistant",
#    'Arbor_Armament',
#    'Unwind'],
#   ['Stronghold_Confessor',
#    'Relic_Runner',
#    'Cold-Water_Snapper',
#    'Tolarian_Scholar'],
#   ['Guardians_of_Koilos', 'Ghitu_Lavarunner', 'Amaranthine_Wall'],
#   ['Rat_Colony', 'Homarid_Explorer'],
#   ['Tragic_Poet']],
#  [['Settle_the_Score',
#    'Helm_of_the_Host',
#    "Raff_Capashen_Ship's_Mage",
#    'Keldon_Overseer',
#    'Sergeant-at-Arms',
#    'Adeliz_the_Cinder_Wind',
#    'Windgrace_Acolyte',
#    "Curator's_Ward",
#    'Saproling_Migration',
#    'Sparring_Construct',
#    'Adamant_Will',
#    "Gaea's_Protector",
#    'Radiating_Lightning',
#    'Ghitu_Lavarunner'],
#   ['Windgrace_Acolyte',
#    'Memorial_to_Glory',
#    'Daring_Archaeologist',
#    'Firefist_Adept',
#    "On_Serra's_Wings",
#    'Radiating_Lightning',
#    'Lingering_Phantom',
#    'Arcane_Flight',
#    'Broken_Bond',
#    'Short_Sword',
#    'Charge',
#    "Gaea's_Blessing",
#    'Frenzied_Rage'],
#   ['Wild_Onslaught',
#    "Urza's_Tome",
#    'Slinn_Voda_the_Rising_Deep',
#    'Yavimaya_Sapherd',
#    "Gideon's_Reproach",
#    'Cloudreader_Sphinx',
#    'Opt',
#    'Gift_of_Growth',
#    'Jousting_Lance',
#    'Keldon_Warcaller',
#    'Charge',
#    'Ghitu_Chronicler'],
#   ["Navigator's_Compass",
#    "Gideon's_Reproach",
#    'Academy_Journeymage',
#    'Shield_of_the_Realm',
#    'Call_the_Cavalry',
#    'Rescue',
#    'Soul_Salvage',
#    'Opt',
#    'Garna_the_Bloodflame',
#    'Garna_the_Bloodflame',
#    'Adamant_Will'],
#   ['Deathbloom_Thallid',
#    'Clifftop_Retreat',
#    'Deep_Freeze',
#    'Gift_of_Growth',
#    'Call_the_Cavalry',
#    'Serra_Disciple',
#    'Guardians_of_Koilos',
#    'Mammoth_Spider',
#    'Feral_Abomination',
#    'Primordial_Wurm'],
#   ['Grow_from_the_Ashes',
#    'Skittering_Surveyor',
#    'Sergeant-at-Arms',
#    'Adventurous_Impulse',
#    'Stronghold_Confessor',
#    'Ghitu_Lavarunner',
#    'Voltaic_Servant',
#    'Divest',
#    'Rat_Colony'],
#   ['Grow_from_the_Ashes',
#    'Keldon_Overseer',
#    'Opt',
#    'Gift_of_Growth',
#    'Excavation_Elephant',
#    'Squee_the_Immortal',
#    'Cabal_Evangel',
#    'Frenzied_Rage'],
#   ['Slimefoot_the_Stowaway',
#    'Dub',
#    'Divination',
#    'Pierce_the_Sky',
#    'Thallid_Omnivore',
#    'Fire_Elemental',
#    'Feral_Abomination'],
#   ['Saproling_Migration',
#    'Sparring_Construct',
#    'Adamant_Will',
#    "Gaea's_Protector",
#    'Radiating_Lightning',
#    'Ghitu_Lavarunner'],
#   ['Broken_Bond', 'Short_Sword', 'Charge', "Gaea's_Blessing", 'Frenzied_Rage'],
#   ['Jousting_Lance', 'Keldon_Warcaller', 'Charge', 'Ghitu_Chronicler'],
#   ['Garna_the_Bloodflame', 'Garna_the_Bloodflame', 'Adamant_Will'],
#   ['Feral_Abomination', 'Primordial_Wurm'],
#   ['Rat_Colony']],
#  [['Vicious_Offering',
#    'Serra_Angel',
#    'Weight_of_Memory',
#    "Navigator's_Compass",
#    'Call_the_Cavalry',
#    'Sulfur_Falls',
#    'Rona_Disciple_of_Gix',
#    'Rescue',
#    'Skittering_Surveyor',
#    'Radiating_Lightning',
#    'Invoke_the_Divine',
#    'Seismic_Shift',
#    'Charge',
#    "Gaea's_Protector"],
#   ['Cast_Down',
#    "Jaya's_Immolating_Inferno",
#    "Raff_Capashen_Ship's_Mage",
#    "Wizard's_Lightning",
#    "D'Avenant_Trapper",
#    'Shivan_Fire',
#    'Fungal_Infection',
#    'Syncopate',
#    "Gaea's_Protector",
#    'Keldon_Overseer',
#    'Guardians_of_Koilos',
#    "Warlord's_Fury",
#    'Cabal_Evangel'],
#   ['Dark_Bargain',
#    'Shivan_Fire',
#    'Blessed_Light',
#    'Gift_of_Growth',
#    'Aven_Sentry',
#    'Adeliz_the_Cinder_Wind',
#    'Syncopate',
#    'Zhalfirin_Void',
#    'Benalish_Honor_Guard',
#    'Fire_Elemental',
#    'The_Antiquities_War',
#    'Skirk_Prospector'],
#   ['Fungal_Infection',
#    'Aven_Sentry',
#    'Academy_Drake',
#    "Sorcerer's_Wand",
#    'Soul_Salvage',
#    'Academy_Journeymage',
#    'Divination',
#    'Powerstone_Shard',
#    'Demonic_Vigor',
#    'Radiating_Lightning',
#    'Board_the_Weatherlight'],
#   ['Spore_Swarm',
#    'Healing_Grace',
#    'Opt',
#    'Grow_from_the_Ashes',
#    'Memorial_to_Folly',
#    "Artificer's_Assistant",
#    'Drudge_Sentinel',
#    "Gaea's_Protector",
#    "Warlord's_Fury",
#    'Ghitu_Lavarunner'],
#   ['Slimefoot_the_Stowaway',
#    'Rampaging_Cyclops',
#    'Aven_Sentry',
#    'Broken_Bond',
#    'Excavation_Elephant',
#    'Guardians_of_Koilos',
#    'Divest',
#    'Tragic_Poet',
#    'Cabal_Stronghold'],
#   ['Bloodtallow_Candle',
#    'Keldon_Overseer',
#    'Invoke_the_Divine',
#    'Firefist_Adept',
#    'Powerstone_Shard',
#    'Seismic_Shift',
#    'Rat_Colony',
#    'Tragic_Poet'],
#   ['Soul_Salvage',
#    'Thallid_Omnivore',
#    "Artificer's_Assistant",
#    'Llanowar_Scout',
#    'Mammoth_Spider',
#    'Adventurous_Impulse',
#    'Oath_of_Teferi'],
#   ['Skittering_Surveyor',
#    'Radiating_Lightning',
#    'Invoke_the_Divine',
#    'Seismic_Shift',
#    'Charge',
#    "Gaea's_Protector"],
#   ["Gaea's_Protector",
#    'Keldon_Overseer',
#    'Guardians_of_Koilos',
#    "Warlord's_Fury",
#    'Cabal_Evangel'],
#   ['Benalish_Honor_Guard',
#    'Fire_Elemental',
#    'The_Antiquities_War',
#    'Skirk_Prospector'],
#   ['Demonic_Vigor', 'Radiating_Lightning', 'Board_the_Weatherlight'],
#   ["Warlord's_Fury", 'Ghitu_Lavarunner'],
#   ['Cabal_Stronghold']]]

# %%
test = alldrafts[:1000]
train = alldrafts[1000:]

# %%
d = vectorize_draft(
    parse_draft_to_flooey_format(load_draft(train[0])),
    cardset
)

# %%
d['draft_x'].shape, d['draft_y'].shape
# Out:
# ((3, 14, 500), (3, 14, 250))

# %%
def DraftGenerator(trainset, batch_size=20):
    for i in range(0, len(trainset) / batch_size):
        flooey_drafts = [
            parse_draft_to_flooey_format(load_draft(draft))
            for draft in trainset[i*batch_size:(i+1)*batch_size]
        ]
        draftsv = [vectorize_draft(draft, cardset) for draft in flooey_drafts]
        X, Y = [], []
        for draft in draftsv:
            draft_x = draft['draft_x']
            draft_y = draft['draft_y']
            for pack in range(len(draft_x)):
                for pick in range(len(draft_x[pack])):
                    Y.append(draft_y[pack][pick])
                    X.append(draft_x[pack][pick].flatten())
        yield (np.array(X), np.array(Y))

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

# %%
model = Sequential()
model.add(Dense(
    512, activation='relu',
    # input_shape=[3, 14, len(cardset) * 2])
    input_dim=len(cardset) * 2
))
model.add(Dropout(0.2))
model.add(Dense(512))
model.add(Dense(len(cardset), activation='softmax'))
model.compile(
    optimizer='rmsprop',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
dg = DraftGenerator(train)

# %%
model.fit_generator(dg, steps_per_epoch=2000, epochs=5)
# Out:
# Epoch 1/5
#  120/2000 [>.............................] - ETA: 2:37 - loss: 1.1612 - acc: 0.5704
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-c86aaf68475b> in <module>()
# ----> 1 model.fit_generator(dg, steps_per_epoch=2000, epochs=5)
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/keras/models.pyc in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1225                                         use_multiprocessing=use_multiprocessing,
#    1226                                         shuffle=shuffle,
# -> 1227                                         initial_epoch=initial_epoch)
#    1228
#    1229     @interfaces.legacy_generator_methods_support
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2113                 batch_index = 0
#    2114                 while steps_done < steps_per_epoch:
# -> 2115                     generator_output = next(output_generator)
#    2116
#    2117                     if not hasattr(generator_output, '__len__'):
#
# /Users/zswitten/.pyenv/versions/2.7.12/lib/python2.7/site-packages/keras/utils/data_utils.pyc in get(self)
#     727                     raise StopIteration()
#     728                 else:
# --> 729                     time.sleep(self.wait_time)
#     730
#     731         # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:
